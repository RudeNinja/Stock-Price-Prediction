# %% [markdown]
# # Google Stock Prediction using ML

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib. pyplot as plt
import matplotlib
from sklearn. preprocessing import MinMaxScaler
from keras. layers import LSTM, Dense, Dropout
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib. dates as mandates
from sklearn. preprocessing import MinMaxScaler
from sklearn import linear_model
from keras. models import Sequential
from keras. layers import Dense
import keras. backend as K
from keras. callbacks import EarlyStopping
from keras. optimizers import adam
from keras. models import load_model
from keras. layers import LSTM
from keras. utils.vis_utils import plot_model

# %%
df=pd.read_csv('/content/drive/MyDrive/TSLA.csv',index_col='Date',parse_dates=True,infer_datetime_format=True)
df.head()
# Out:
#                  Open   High        Low      Close  Adj Close    Volume
# Date
# 2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 2010-07-02  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 2010-07-06  20.000000  20.00  15.830000  16.110001  16.110001   6866900

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df['Adj Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Normalizing the Dataset

# %%
output_var = pd.DataFrame(df['Adj Close'])

features = ['Open','High','Low','Volume']

# %%
scaler = MinMaxScaler()
feature_transform = scaler.fit_transform(df[features])
feature_transform= pd.DataFrame(columns=features, data=feature_transform, index=df.index)
feature_transform.head()
# Out:
#                 Open      High       Low    Volume
# Date
# 2010-06-29  0.004349  0.010877  0.003887  0.397214
# 2010-06-30  0.014676  0.017920  0.012634  0.363576
# 2010-07-01  0.013474  0.012073  0.008033  0.172543
# 2010-07-02  0.010433  0.008408  0.005664  0.106958
# 2010-07-06  0.005870  0.004379  0.001291  0.143747

# %%
timesplit= TimeSeriesSplit(n_splits=10)
for train_index, test_index in timesplit.split(feature_transform):
        X_train, X_test = feature_transform[:len(train_index)], feature_transform[len(train_index): (len(train_index)+len(test_index))]
        y_train, y_test = output_var[:len(train_index)].values.ravel(), output_var[len(train_index): (len(train_index)+len(test_index))].values.ravel()

# %%
trainX =np.array(X_train)
testX =np.array(X_test)
X_train = trainX.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test = testX.reshape(X_test.shape[0], 1, X_test.shape[1])

print(X_test.shape)



regressor = Sequential()

regressor.add(LSTM(units = 64, return_sequences=True, input_shape = (1,X_test.shape[2]),activation='relu'))
regressor.add(LSTM(units = 64, return_sequences=False, activation='relu'))

regressor.add(Dense(1))
# Out:
# (219, 1, 4)
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
plot_model(regressor,show_shapes=True,show_layer_names=True)

# %%
history=regressor.fit(X_train, y_train, epochs=100, batch_size=8, verbose=1, shuffle=False)
# Out:
# Epoch 1/100
# 275/275 [==============================] - 11s 12ms/step - loss: 22900.4121
# Epoch 2/100
# 275/275 [==============================] - 2s 9ms/step - loss: 1074.8613
# Epoch 3/100
# 275/275 [==============================] - 3s 9ms/step - loss: 721.8308
# Epoch 4/100
# 275/275 [==============================] - 2s 9ms/step - loss: 370.5222
# Epoch 5/100
# 275/275 [==============================] - 4s 13ms/step - loss: 271.8882
# Epoch 6/100
# 275/275 [==============================] - 3s 11ms/step - loss: 216.4900
# Epoch 7/100
# 275/275 [==============================] - 2s 9ms/step - loss: 175.4818
# Epoch 8/100
# 275/275 [==============================] - 2s 9ms/step - loss: 143.3796
# Epoch 9/100
# 275/275 [==============================] - 2s 8ms/step - loss: 118.1255
# Epoch 10/100
# 275/275 [==============================] - 3s 13ms/step - loss: 98.3423
# Epoch 11/100
# 275/275 [==============================] - 3s 12ms/step - loss: 82.9150
# Epoch 12/100
# 275/275 [==============================] - 2s 8ms/step - loss: 70.9164
# Epoch 13/100
# 275/275 [==============================] - 2s 9ms/step - loss: 61.5830
# Epoch 53/100
# 275/275 [==============================] - 2s 9ms/step - loss: 16.4939
# Epoch 54/100
# 275/275 [==============================] - 2s 9ms/step - loss: 16.3043
# Epoch 55/100
# 275/275 [==============================] - 3s 11ms/step - loss: 16.1275
# Epoch 56/100
# 275/275 [==============================] - 4s 13ms/step - loss: 15.9634
# Epoch 57/100
# 275/275 [==============================] - 2s 9ms/step - loss: 15.8116
# Epoch 58/100
# 275/275 [==============================] - 2s 9ms/step - loss: 15.6718
# Epoch 59/100
# 275/275 [==============================] - 2s 9ms/step - loss: 15.5437
# Epoch 60/100
# 275/275 [==============================] - 3s 12ms/step - loss: 15.4266
# Epoch 61/100
# 275/275 [==============================] - 4s 14ms/step - loss: 15.3202
# Epoch 62/100
# 275/275 [==============================] - 2s 9ms/step - loss: 15.2236
# Epoch 63/100
# 275/275 [==============================] - 2s 9ms/step - loss: 15.1362
# Epoch 64/100
# 275/275 [==============================] - 2s 9ms/step - loss: 15.0573
# Epoch 65/100
# 275/275 [==============================] - 3s 11ms/step - loss: 14.9861
# Epoch 66/100
# 275/275 [==============================] - 4s 14ms/step - loss: 14.9220
# Epoch 67/100
# 275/275 [==============================] - 2s 9ms/step - loss: 14.8642
# Epoch 68/100
# 275/275 [==============================] - 2s 9ms/step - loss: 14.8122
# Epoch 69/100
# 275/275 [==============================] - 2s 9ms/step - loss: 14.7652
# Epoch 70/100
# 275/275 [==============================] - 3s 11ms/step - loss: 14.7227
# Epoch 71/100
# 275/275 [==============================] - 4s 13ms/step - loss: 14.6843
# Epoch 72/100
# 275/275 [==============================] - 2s 9ms/step - loss: 14.6494
# Epoch 73/100
# 275/275 [==============================] - 2s 9ms/step - loss: 14.6176
# Epoch 74/100
# 275/275 [==============================] - 3s 9ms/step - loss: 14.5885
# Epoch 75/100
# 275/275 [==============================] - 4s 13ms/step - loss: 14.5617
# Epoch 76/100
# 275/275 [==============================] - 3s 13ms/step - loss: 14.5371
# Epoch 77/100
# 275/275 [==============================] - 2s 9ms/step - loss: 14.5142
# Epoch 78/100
# 275/275 [==============================] - 2s 9ms/step - loss: 14.4928
# Epoch 79/100
# 275/275 [==============================] - 2s 9ms/step - loss: 14.4726
# Epoch 80/100
# 275/275 [==============================] - 4s 14ms/step - loss: 14.4536
# Epoch 81/100
# 275/275 [==============================] - 3s 11ms/step - loss: 14.4355
# Epoch 82/100
# 275/275 [==============================] - 3s 9ms/step - loss: 14.4181
# Epoch 83/100
# 275/275 [==============================] - 2s 9ms/step - loss: 14.4012
# Epoch 84/100
# 275/275 [==============================] - 2s 9ms/step - loss: 14.3849
# Epoch 85/100
# 275/275 [==============================] - 4s 14ms/step - loss: 14.3689
# Epoch 86/100
# 275/275 [==============================] - 3s 11ms/step - loss: 14.3531
# Epoch 87/100
# 275/275 [==============================] - 2s 9ms/step - loss: 14.3375
# Epoch 88/100
# 275/275 [==============================] - 2s 9ms/step - loss: 14.3220
# Epoch 89/100
# 275/275 [==============================] - 2s 9ms/step - loss: 14.3065
# Epoch 90/100
# 275/275 [==============================] - 4s 14ms/step - loss: 14.2910
# Epoch 91/100
# 275/275 [==============================] - 3s 10ms/step - loss: 14.2755
# Epoch 92/100
# 275/275 [==============================] - 2s 9ms/step - loss: 14.2598
# Epoch 93/100
# 275/275 [==============================] - 2s 9ms/step - loss: 14.2439
# Epoch 94/100
# 275/275 [==============================] - 2s 9ms/step - loss: 14.2280
# Epoch 95/100
# 275/275 [==============================] - 4s 14ms/step - loss: 14.2118
# Epoch 96/100
# 275/275 [==============================] - 3s 11ms/step - loss: 14.1954
# Epoch 97/100
# 275/275 [==============================] - 2s 9ms/step - loss: 14.1788
# Epoch 98/100
# 275/275 [==============================] - 2s 9ms/step - loss: 14.1619
# Epoch 99/100
# 275/275 [==============================] - 4s 16ms/step - loss: 14.1449
# Epoch 100/100
# 275/275 [==============================] - 4s 15ms/step - loss: 14.1276

# %%
y_pred= regressor.predict(X_test)
# Out:
# 7/7 [==============================] - 0s 3ms/step

# %%
plt.plot(y_test, label='True Value')
plt.plot(y_pred, label='LSTM Value')
plt.title('Prediction by LSTM')
plt.xlabel('Time Scale')
plt.ylabel('Scaled USD')
plt.legend()
plt.show()
